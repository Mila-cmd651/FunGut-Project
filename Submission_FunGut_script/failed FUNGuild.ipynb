# %% [markdown]
# # 1. Import Packages

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import qiime2 as q2
from qiime2 import Visualization
from scipy.stats import shapiro, kruskal, f_oneway

# %% [markdown]
# # 2. Data Directionary

# %%
# Location
data_dir = "Project_data/FUNGuild"
! mkdir -p "$data_dir"

# %%
# Paths to project inputs
input_table    = "Project_data/Taxonomy/table_filtered.qza"
input_taxonomy = "Project_data/Taxonomy/taxonomy_pretrained.qza"
input_metadata = "Project_data/Metadata/updated_fungut_metadata.tsv"

# %% [markdown]
# # 3. Export QIIME2 Artifacts to TSV

# %%
# Export taxonomy file
! qiime tools export \
    --input-path "$input_taxonomy" \
    --output-path "$data_dir"

# Export feature table (BIOM)
! qiime tools export \
    --input-path "$input_table" \
    --output-path "$data_dir"
# Out:
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Exported Project_data/Taxonomy/taxonomy_pretrained.qza as TSVTaxonomyDirectoryFormat to directory Project_data/FUNGuild
# /opt/conda/lib/python3.10/site-packages/unifrac/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Exported Project_data/Taxonomy/table_filtered.qza as BIOMV210DirFmt to directory Project_data/FUNGuild
# All QIIME2 artifacts exported into: Project_data/FUNGuild

# %%
# Convert BIOM → TSV
biom_path = f"{data_dir}/feature-table.biom"
tsv_path = f"{data_dir}/feature-table.tsv"

! biom convert \
    -i "$biom_path" \
    -o "$tsv_path" \
    --to-tsv

# %% [markdown]
# # 4. Build FUNGuild input table

# %%
feature_tsv = f"{data_dir}/feature-table.tsv"

# Load feature table
feature_df = pd.read_csv(feature_tsv, sep="\t", skiprows=[0], index_col=0)

print("Feature table shape:", feature_df.shape)
feature_df.head()
# Out:
# Feature table shape: (895, 150)
#                                   ERR5327198  ERR5327199  ERR5327266  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327282  ERR5327284  ERR5327285  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327287  ERR5327288  ERR5327289  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327300  ...  ERR5327586  ERR5327587  \
# #OTU ID                                       ...
# 4306469410ceb9944820bcea0e5952b2         0.0  ...         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0  ...         0.0     16772.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0  ...         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0  ...         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0  ...         0.0         0.0
#
#                                   ERR5327591  ERR5327592  ERR5327596  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327599  ERR5327604  ERR5327605  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327615  ERR5327620
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0
#
# [5 rows x 150 columns]

# %%
tax_tsv     = f"{data_dir}/taxonomy.tsv"

# Load taxonomy table
tax_df = pd.read_csv(tax_tsv, sep='\t', comment='#')
tax_df = tax_df.rename(columns={"Feature ID": "feature_id",
                                "Taxon": "taxonomy"})

tax_df.head()
# Out:
#                          feature_id  \
# 0  f872ab159e2219de905e49b556b85d05
# 1  d3b20e3fa30a65662fc3a6e0057d6e90
# 2  333df8f222ab30bfdffd5b7d3c5a789b
# 3  beba691fc7ee5c7219589a54ec45b0bd
# 4  5e7d76c82d92bc95d366c4c5796d3b21
#
#                                             taxonomy  Confidence
# 0  k__Fungi;p__Ascomycota;c__Saccharomycetes;o__S...    0.999972
# 1  k__Fungi;p__Ascomycota;c__Ascomycota_cls_Incer...    0.999984
# 2  k__Fungi;p__Ascomycota;c__Saccharomycetes;o__S...    0.918087
# 3  k__Fungi;p__Ascomycota;c__Eurotiomycetes;o__Eu...    0.841928
# 4                                         Unassigned    0.380525

# %%
# Merge counts + taxonomy into one table

# Make taxonomy a Series indexed by feature_id
tax_series = tax_df.set_index("feature_id")["taxonomy"]

# Join feature table with taxonomy using the feature IDs
funguild_input = feature_df.join(tax_series, how="left")

# Drop features without taxonomy
#funguild_input = funguild_input.dropna(subset=["taxonomy"])

print("FUNGuild input shape:", funguild_input.shape)
funguild_input.head()
# Out:
# FUNGuild input shape: (895, 151)
#                                   ERR5327198  ERR5327199  ERR5327266  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327282  ERR5327284  ERR5327285  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327287  ERR5327288  ERR5327289  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327300  ...  ERR5327587  ERR5327591  \
# #OTU ID                                       ...
# 4306469410ceb9944820bcea0e5952b2         0.0  ...         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0  ...     16772.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0  ...         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0  ...         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0  ...         0.0         0.0
#
#                                   ERR5327592  ERR5327596  ERR5327599  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327604  ERR5327605  ERR5327615  \
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0         0.0         0.0
# f817ec6ce9c52036235cf4002fffa65e         0.0         0.0         0.0
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0         0.0         0.0
# 633ec982f89c4772064757cec6e7d3ad         0.0         0.0         0.0
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0         0.0         0.0
#
#                                   ERR5327620  taxonomy
# #OTU ID
# 4306469410ceb9944820bcea0e5952b2         0.0       NaN
# f817ec6ce9c52036235cf4002fffa65e         0.0       NaN
# 6ccbc16d6454d876ebb3cc5428d78b65         0.0       NaN
# 633ec982f89c4772064757cec6e7d3ad         0.0       NaN
# ffafb7e58eb5ffd894cf6b5a4610dc89         0.0       NaN
#
# [5 rows x 151 columns]

# %%
# Save table
funguild_input_path = f"{data_dir}/funguild_input.txt"
funguild_input.to_csv(funguild_input_path, sep="\t")

print("Saved FUNGuild input to:", funguild_input_path)

# %%
print("Feature table index (first 5):")
print(feature_df.index[:5])
print("dtype:", feature_df.index.dtype)

print("\nTaxonomy feature_id (first 5):")
print(tax_df["feature_id"].head())
print("dtype:", tax_df["feature_id"].dtype)
# Out:
# Feature table index (first 5):
# Index(['4306469410ceb9944820bcea0e5952b2', 'f817ec6ce9c52036235cf4002fffa65e',
#        '6ccbc16d6454d876ebb3cc5428d78b65', '633ec982f89c4772064757cec6e7d3ad',
#        'ffafb7e58eb5ffd894cf6b5a4610dc89'],
#       dtype='object', name='#OTU ID')
# dtype: object
#
# Taxonomy feature_id (first 5):
# 0    f872ab159e2219de905e49b556b85d05
# 1    d3b20e3fa30a65662fc3a6e0057d6e90
# 2    333df8f222ab30bfdffd5b7d3c5a789b
# 3    beba691fc7ee5c7219589a54ec45b0bd
# 4    5e7d76c82d92bc95d366c4c5796d3b21
# Name: feature_id, dtype: object
# dtype: object

# %%
shared_ids = set(feature_df.index) & set(tax_df["feature_id"])
print("Number of shared IDs:", len(shared_ids))
# Out:
# Number of shared IDs: 0
